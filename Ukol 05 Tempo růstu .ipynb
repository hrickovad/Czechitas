# %% [markdown]
# Tempo růstu
#
# Pokračuj v práci s daty o kryptoměnách.
#
# Z datového souboru si vyber jednu kryptoměnu a urči průměrné denní tempo růstu měny za sledované období.
#
# Můžeš využít funkci geometric_mean z modulu statistics.
#
# Vyber si sloupec se změnou ceny, kterou máš vypočítanou z předchozího cvičení (případně si jej dopočti), přičti k němu 1 (nemusíš dělit stem jako v lekci, hodnoty jsou jako desetinná čísla, nikoli jako procenta) a převeď jej na seznam pomocí metody .tolist().
#
# Následně vypočti geometrický průměr z těchto hodnot.
#
# Např. pro měnu XMR (Monero) vychází průměrný mezidenní růst ceny na 0.001794558895.

# %%
import pandas as pd
import requests
import statistics
from scipy.stats.mstats import gmean

# %%
r = requests.get("https://raw.githubusercontent.com/pesikj/progr2-python/master/data/crypto_prices.csv")
open("crypto_prices.csv", "wb").write(r.content)
# Out:
# 5312466

# %%
crypto_prices = pd.read_csv('crypto_prices.csv')

# %%
crypto_prices = pd.DataFrame(data = crypto_prices)

# %%
crypto_prices = crypto_prices.sort_values(['Date'])

# %%
 crypto_prices['Change'] = crypto_prices.groupby(['Name'])['Close'].pct_change()

# %%
crypto_prices = crypto_prices.pivot(index="Date", columns="Symbol", values="Change")
crypto_prices
# Out:
# Symbol                   AAVE       ADA      ATOM       BNB       BTC  \
# Date
# 2013-04-29 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-04-30 23:59:59       NaN       NaN       NaN       NaN -0.038328
# 2013-05-01 23:59:59       NaN       NaN       NaN       NaN -0.158345
# 2013-05-02 23:59:59       NaN       NaN       NaN       NaN -0.100692
# 2013-05-03 23:59:59       NaN       NaN       NaN       NaN -0.070906
# ...                       ...       ...       ...       ...       ...
# 2021-07-02 23:59:59  0.010025  0.044014  0.058912 -0.002759  0.009679
# 2021-07-03 23:59:59  0.109882  0.008921  0.004505  0.037624  0.022760
# 2021-07-04 23:59:59  0.066949  0.036499  0.037707  0.031837  0.017861
# 2021-07-05 23:59:59  0.111141 -0.036543  0.104776 -0.017399 -0.043692
# 2021-07-06 23:59:59  0.029463  0.009363 -0.028719  0.061370  0.014496
#
# Symbol                    CRO      DOGE       DOT       EOS       ETH  ...  \
# Date                                                                   ...
# 2013-04-29 23:59:59       NaN       NaN       NaN       NaN       NaN  ...
# 2013-04-30 23:59:59       NaN       NaN       NaN       NaN       NaN  ...
# 2013-05-01 23:59:59       NaN       NaN       NaN       NaN       NaN  ...
# 2013-05-02 23:59:59       NaN       NaN       NaN       NaN       NaN  ...
# 2013-05-03 23:59:59       NaN       NaN       NaN       NaN       NaN  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2021-07-02 23:59:59  0.016064  0.002921  0.004045 -0.000990  0.017238  ...
# 2021-07-03 23:59:59  0.039442  0.004677  0.013881  0.028492  0.035383  ...
# 2021-07-04 23:59:59  0.033957  0.000292  0.029595  0.003338  0.042949  ...
# 2021-07-05 23:59:59 -0.054020 -0.060323 -0.048610 -0.059278 -0.053039  ...
# 2021-07-06 23:59:59  0.060808  0.012121  0.059596  0.016511  0.057354  ...
#
# Symbol                    SOL       TRX       UNI      USDC      USDT  \
# Date
# 2013-04-29 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-04-30 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-05-01 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-05-02 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-05-03 23:59:59       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 2021-07-02 23:59:59  0.018454  0.024932  0.020779 -0.000157 -0.000194
# 2021-07-03 23:59:59  0.013472  0.004519  0.070335 -0.000051 -0.000076
# 2021-07-04 23:59:59 -0.004879  0.007269  0.063874 -0.000484 -0.000455
# 2021-07-05 23:59:59 -0.038647 -0.040478 -0.032577  0.001028  0.001167
# 2021-07-06 23:59:59  0.038944  0.005590  0.114704 -0.000469 -0.000577
#
# Symbol                   WBTC       XEM       XLM       XMR       XRP
# Date
# 2013-04-29 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-04-30 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-05-01 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-05-02 23:59:59       NaN       NaN       NaN       NaN       NaN
# 2013-05-03 23:59:59       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 2021-07-02 23:59:59  0.009106  0.024803 -0.023423  0.023147 -0.006681
# 2021-07-03 23:59:59  0.025210  0.025111  0.003405  0.016124  0.024553
# 2021-07-04 23:59:59  0.017671  0.021231  0.014391  0.023695  0.032780
# 2021-07-05 23:59:59 -0.042026 -0.050973 -0.050990 -0.024456 -0.058487
# 2021-07-06 23:59:59  0.011321  0.022881  0.022531  0.035773  0.016968
#
# [2991 rows x 23 columns]

# %%
gmean((crypto_prices["XMR"] + 1).dropna().tolist()) - 1
# Out:
# 0.001794558895297893

# %%
# zvolila som menu ako je v zadani, aby som si to skontrolovala a sedi to :-)
